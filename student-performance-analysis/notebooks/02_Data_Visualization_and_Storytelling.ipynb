# %%
# 📦 Importing Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
# 📥 Load the Dataset
df = pd.read_csv("../data/Student_Habits_Dataset.csv")
df.drop(columns=["Student_ID"], inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#    Study_Hours_Per_Day  Sleep_Hours_Per_Day  Screen_Time_Per_Day  \
# 0                  3.7                  6.2                  5.7
# 1                  2.8                  6.6                  5.6
# 2                  4.0                  6.3                  3.1
# 3                  5.3                  7.1                  6.2
# 4                  2.6                  8.4                  2.0
#
#    Physical_Activity_Hours  Attendance_Percentage  Healthy_Eating_Score  \
# 0                      0.0                   80.3                     8
# 1                      0.5                   95.1                     4
# 2                      0.7                   83.0                    10
# 3                      1.1                   85.9                     4
# 4                      1.5                   92.2                     2
#
#    Academic_Performance
# 0                  48.6
# 1                  32.8
# 2                  44.4
# 3                  54.1
# ...

# %% [markdown]
# ### 🎓 Attendance vs Academic Performance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Attendance_Percentage",
    y="Academic_Performance",
    hue="Physical_Activity_Hours",  # numerical hue is okay with a continuous color palette
    palette="coolwarm"
)
plt.title("Attendance vs Academic Performance")
plt.xlabel("Attendance (%)")
plt.ylabel("Academic Performance")
plt.show()

# %% [markdown]
# ### 📘 Study Hours vs Academic Performance

# %%
plt.figure(figsize=(8, 5))
sns.regplot(
    data=df,
    x="Study_Hours_Per_Day",
    y="Academic_Performance",
    scatter_kws={'alpha': 0.6}
)
plt.title("Study Hours vs Academic Performance")
plt.xlabel("Study Hours per Day")
plt.ylabel("Academic Performance")
plt.show()

# %% [markdown]
# ### 😴 Sleep Duration vs Academic Performance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("../data/Student_Habits_Dataset.csv")

# Plot with color using hue
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="Sleep_Hours_Per_Day", y="Academic_Performance",
            hue="Sleep_Hours_Per_Day", palette="Set3", legend=False)
plt.title("Sleep Duration vs Academic Performance")
plt.xlabel("Sleep Duration (Hours)")
plt.ylabel("Academic Performance")
plt.show()

# %% [markdown]
# ### 📱 Screen Time vs Academic Performance

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Screen_Time_Per_Day",
    y="Academic_Performance",
    hue="Attendance_Percentage",  # Optional
    palette="coolwarm"
)
plt.title("Screen Time vs Academic Performance")
plt.xlabel("Screen Time (Hours per Day)")
plt.ylabel("Academic Performance")
plt.show()

# %% [markdown]
# ### 🔥 Correlation Heatmap

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Correlation Between Variables")
plt.show()

# %% [markdown]
# ## 🧠 Key Insights & Storytelling
#
# - ✅ Students with higher study hours, good sleep, and regular physical activity tend to score higher academically.
# - 📉 High screen time shows a mild negative relationship with performance.
# - 🎯 Attendance strongly correlates with better academic results, highlighting its importance.
# - 🧪 These patterns suggest maintaining a balanced lifestyle improves academic outcomes.
